# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio

# %% [markdown]
# ### Passo a Passo de um Projeto de Ciência de Dados
#
# - Passo 1: Entendimento do Desafio
# - Passo 2: Entendimento da Área/Empresa
# - Passo 3: Extração/Obtenção de Dados
# - Passo 4: Ajuste de Dados (Tratamento/Limpeza)
# - Passo 5: Análise Exploratória
# - Passo 6: Modelagem + Algoritmos (Aqui que entra a Inteligência Artificial, se necessário)
# - Passo 7: Interpretação de Resultados

# %% [markdown]
# # Projeto Ciência de Dados - Previsão de Vendas
#
# - Nosso desafio é conseguir prever as vendas que vamos ter em determinado período com base nos gastos em anúncios nas 3 grandes redes que a empresa Hashtag investe: TV, Jornal e Rádio
# - TV, Jornal e Rádio estão em milhares de reais
# - Vendas estão em milhões

# %% [markdown]
# #### Importar a Base de dados

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in d:\users\angelica\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six in d:\users\angelica\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in d:\users\angelica\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in d:\users\angelica\anaconda3\lib\site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in d:\users\angelica\anaconda3\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pandas>=0.23 in d:\users\angelica\anaconda3\lib\site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in d:\users\angelica\anaconda3\lib\site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\angelica\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six in d:\users\angelica\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in d:\users\angelica\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: scikit-learn in d:\users\angelica\anaconda3\lib\site-packages (0.24.2)
# Requirement already satisfied: joblib>=0.11 in d:\users\angelica\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\angelica\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in d:\users\angelica\anaconda3\lib\site-packages (from scikit-learn) (1.20.3)
# Requirement already satisfied: scipy>=0.19.1 in d:\users\angelica\anaconda3\lib\site-packages (from scikit-learn) (1.7.1)

# %%
import pandas as pd

tabela = pd.read_csv("advertising.csv")
display(tabela)

#tratamento de dados
print(tabela.info())
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Radio   200 non-null    float64
#  2   Jornal  200 non-null    float64
#  3   Vendas  200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB
# None

# %% [raw]
# ####Análise Exploratória
# - Vamos tentar visualizar como as informações de cada item estão distribuídas
# - Vamos ver a correlação entre cada um dos itens

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#criar gráfico
sns.heatmap(tabela.corr(), cmap="flare", annot=True)

#exibir gráfico
plt.show()

# %% [markdown]
# #### Com isso, podemos partir para a preparação dos dados para treinarmos o Modelo de Machine Learning
#
# - Separando em dados de treino e dados de teste

# %%
from sklearn.model_selection import train_test_split #separar dandos em x e y

y = tabela["Vendas"] #que quero prover
x = tabela.drop("Vendas", axis=1) #quem vou usar pra fazer previsão

#separar treino e teste

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# #### Temos um problema de regressão - Vamos escolher os modelos que vamos usar:
#
# - Regressão Linear
# - RandomForest (Árvore de Decisão)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

#para criar a inteligência artificial

modelo_regressaolinear = LinearRegression()
modelo_arvoredecisao = RandomForestRegressor()

#para treinar a AI

modelo_regressaolinear.fit(x_treino, y_treino)
modelo_arvoredecisao.fit(x_treino, y_treino)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Teste da AI e Avaliação do Melhor Modelo
#
# - Vamos usar o R² -> diz o % que o nosso modelo consegue explicar o que acontece

# %%
from sklearn import metrics

# criar as previsoes
previsao_regressaolinear = modelo_regressaolinear.predict(x_teste)
previsao_arvoredecisao = modelo_arvoredecisao.predict(x_teste)

# comparar os modelos
print(metrics.r2_score(y_teste, previsao_regressaolinear))
print(metrics.r2_score(y_teste, previsao_arvoredecisao))
# Out:
# 0.9071151423684273
# 0.9629561303264953

# %% [markdown]
# #### Visualização Gráfica das Previsões

# %%
#Árvore da decisão é o melhor modelo

tabela_auxiliar = pd.DataFrame()
tabela_auxiliar["y_teste"] = y_teste
tabela_auxiliar["Previsoes ArvoreDecisao"] = previsao_arvoredecisao
tabela_auxiliar["Previsoes Regressao Linear"] = previsao_regressaolinear

plt.figure(figsize=(15,6))
sns.lineplot(data=tabela_auxiliar)
plt.show()

# %% [markdown]
# #### Como fazer uma nova previsão?

# %%
# importar a nova_tabela com o pandas (a nova tabela tem que ter os dados de TV, Radio e Jornal)
# previsao = modelo_randomforest.predict(nova_tabela)
# print(previsao)

novos = pd.read_csv("novos.csv")
display(novos)

previsao = modelo_arvoredecisao.predict(novos)
print(previsao)
# Out:
#       TV  Radio  Jornal
# 0   23.1    3.8    69.2
# 1   44.5    0.0     5.1
# 2  170.2   45.9     0.0
# [ 7.721  8.672 19.963]
