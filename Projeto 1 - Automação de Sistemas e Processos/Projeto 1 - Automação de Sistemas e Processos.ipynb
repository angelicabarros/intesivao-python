# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>

# %%
#instalação

# !pip install pyautogui
# !pip install pyperclip

# %%
#instalação panda

# !pip install panda

# %%
#importação

import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1 #delay

#abrindo site #estou me sentindo a programadora kkkk

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5) #delay

#abrindo pasta do relatório e fazendo download

pyautogui.click(x=413, y=374, clicks=2)

time.sleep(2) #delay

pyautogui.click(x=456, y=403)
pyautogui.click(x=1156, y=158)
pyautogui.click(x=1001, y=551)

time.sleep(5) #delay

pyautogui.click(x=1082, y=605)

time.sleep(5) #delay

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %%
import pandas as pd

#calculando os indicadores e trazendo a tabela pra cá

tabela = pd.read_excel(r"D:\Users\Angelica\Documents\Vendas - Dez.xlsx")
display(tabela)
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %%
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5) #delay

pyautogui.click(x=76, y=157)

time.sleep(5) #delay

pyautogui.write("pythonimpressionadordiretoria@gmail.com") #email que deve ser encaminhado
pyautogui.press("tab") #selecionando o e-mail

time.sleep(1) #delay

pyautogui.press("tab") #para campo assunto
pyperclip.copy("Relatório agora eu vou programar")

time.sleep(1) #delay

pyautogui.hotkey("ctrl", "v") # escrever o assunto
pyautogui.press("tab") #pular pro corpo do email

time.sleep(1) #delay

texto = f"""
Prezados,

O faturamento de ontem foi de: R${faturamento:,.2f}
A quantidade de produtos foi de: {quantidade:,}

Atenciosamente,
Angélica Barros"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# clicar no botão enviar

# apertar Ctrl Enter
pyautogui.hotkey("ctrl", "enter")

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela

# %%
#achando a posição da minha tela

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=76, y=157)
